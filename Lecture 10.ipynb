# %%
#lecture 10
#OOP
#hide the implementation details: Abstraction

class RentalSys():
    def available_cars(self,requested_cars):
        if requested_cars in self.available_cars:
            print("Available cars are:  1.SUV 2.Hatchback 3.Sedan ")
    
    def cost(self,cars_cost):
        if requested_cars in self.cars_cost:
            print("Costs are: 1.SUV  $100 2.Hatchback $30 3.Sedan ")



class display():
